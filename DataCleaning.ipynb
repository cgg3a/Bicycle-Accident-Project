# %%
# %pip install geopandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
vehicleData = pd.read_csv("VehicleData_OnlyBikes.csv")

# %%
vehicleData.head()
# Out:
#    CRASH_UNIT_ID                                    CRASH_RECORD_ID  \
# 0        1946296  c2dfeac98de6a65fbf5dc7f8d925dffe8fd7558a4205fc...
# 1        1946174  5b2fce0eee4ff07f9fcda30826bb34b1b6a85eba3f2384...
# 2        1946168  fdbdf5b6a8ffd1cb074b56e6c8a6b5adf4130a50ab4422...
# 3        1946020  1f32999a6e8d1bbc008d7d0a24f733f25af5731dac6205...
# 4        1946021  1f32999a6e8d1bbc008d7d0a24f733f25af5731dac6205...
#
#                CRASH_DATE  UNIT_NO UNIT_TYPE  NUM_PASSENGERS  VEHICLE_ID  \
# 0  11/09/2024 10:05:00 PM        2   BICYCLE             NaN         NaN
# 1  11/09/2024 06:30:00 PM        2   BICYCLE             NaN         NaN
# 2  11/09/2024 04:44:00 PM        2   BICYCLE             NaN         NaN
# 3  11/09/2024 03:52:00 PM        2   BICYCLE             NaN         NaN
# 4  11/09/2024 03:52:00 PM        3   BICYCLE             NaN         NaN
#
#    CMRC_VEH_I  MAKE  MODEL  ...  TRAILER1_LENGTH  TRAILER2_LENGTH  \
# ...

# %%
crashData = pd.read_csv("Traffic_Crashes_-_Crashes_20241110.csv")

# %%
crashData.head()
# Out:
#                                      CRASH_RECORD_ID CRASH_DATE_EST_I  \
# 0  6c1659069e9c6285a650e70d6f9b574ed5f64c12888479...              NaN
# 1  5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4...              NaN
# 2  61fcb8c1eb522a6469b460e2134df3d15f82e81fd93e9c...              NaN
# 3  004cd14d0303a9163aad69a2d7f341b7da2a8572b2ab33...              NaN
# 4  a1d5f0ea90897745365a4cbb06cc60329a120d89753fac...              NaN
#
#                CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 0  08/18/2023 12:50:00 PM                  15                  OTHER
# 1  07/29/2023 02:45:00 PM                  30         TRAFFIC SIGNAL
# 2  08/18/2023 05:58:00 PM                  30            NO CONTROLS
# 3  11/26/2019 08:38:00 AM                  25            NO CONTROLS
# 4  08/18/2023 10:45:00 AM                  20            NO CONTROLS
#
#        DEVICE_CONDITION WEATHER_CONDITION LIGHTING_CONDITION  \
# 0  FUNCTIONING PROPERLY             CLEAR           DAYLIGHT
# ...

# %%
# Drop rows with missing needed values
print(crashData.shape[0])
crashData = crashData.dropna(subset=['CRASH_RECORD_ID', 'INJURIES_FATAL', 'LOCATION', 'LATITUDE', 'LONGITUDE'])
print(crashData.shape[0])
# Out:
# 891446
# 883089

# %%
# Last 5 years, ended up not using this...
# crashData[(crashData['CRASH_DATE'].str[6:10]).astype(int) >= 2020]

# %%
temp = pd.merge(crashData, vehicleData, on='CRASH_RECORD_ID')

# %%
allCrashes = temp[['CRASH_RECORD_ID', 'INJURIES_FATAL', 'LOCATION', 'LATITUDE', 'LONGITUDE']]

# %%
fatalCrashes = allCrashes[allCrashes['INJURIES_FATAL'] > 0.0]
nonfatalCrashes = allCrashes[allCrashes['INJURIES_FATAL'] == 0.0]

# %%
allCrashes.to_csv('allCrashes.csv', index=False)
fatalCrashes.to_csv('fatalCrashes.csv', index=False)
nonfatalCrashes.to_csv('nonfatalCrashes.csv', index=False)
